# %%
import pypsa
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="cartopy")

# %%
### BELOW COULD BE SEPARATE CELL IF DESIRE###
network_path = '../results/pypsa/prepared_net.nc'

n = pypsa.Network()
pypsa.Network.import_from_netcdf(network=n, path=network_path)

### BELOW COULD BE SEPARATE CELL IF DESIRE###
# n.optimize(solver_name='gurobi')

### BELOW COULD BE SEPARATE CELL IF DESIRE###
# path_to_save_network =  'results/pypsa/solved_net.nc'
# n.export_to_netcdf(path_to_save_network)
# Out:
# INFO:pypsa.io:Imported network prepared_net.nc has buses, carriers, generators, lines, line_types, links, loads, stores, transformer_types

# %%
n.statistics()
# Out:
#                    Optimal Capacity  Installed Capacity        Supply  \
# Generator -            1.257722e+06        1.257722e+06  1.446589e+07
#           inflow       2.497680e+11        2.497680e+11  9.916518e+10
# Line      AC           8.574789e+04        8.574789e+04  1.609437e+08
# Link      Biomass      1.623224e+04        1.623224e+04  1.212793e+06
#           NG           4.487544e+03        4.487544e+03  2.292131e+06
#           Water        3.830674e+11        3.830674e+11  6.599358e+12
# Load      -            0.000000e+00        0.000000e+00  0.000000e+00
# Store     Biomass      1.000000e+10        1.000000e+10  1.632344e+07
#           NG           1.000000e+10        1.000000e+10  1.457795e+07
#           Water        6.650930e+10        6.650930e+10  1.037491e+11
#           water        6.000000e+15        6.000000e+15  0.000000e+00
#
#                      Withdrawal      Dispatch  Transmission  Capacity Factor  \
# ...
