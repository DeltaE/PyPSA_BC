# %%
from CODERS.coders import CODERSData
DATA_CFG="CODERS/coders.yaml"

# %%
COD=CODERSData(DATA_CFG)
# Out:
# CODERS API key loaded from: CODERS/coders_api.yaml
# user Elias: w0OksqQKMFMtKPbO

# %%
COD.fetch_data("storage")
# Out:
#                         storage_facility_name storage_facility_code  \
# 0                          eReserve 1 Rycroft           AB_ERV1_STO
# 1                    eReserve 2 Buffalo Creek           AB_ERV2_STO
# 2                      eReserve 3 Mercer Hill           AB_ERV3_STO
# 3                                   eReserve4           AB_ERV4_STO
# 4                         eReserve5 Hughenden           AB_ERV5_STO
# 5                                   eReserve6           AB_ERV6_STO
# 6                                   eReserve7           AB_ERV7_STO
# 7                                   eReserve8           AB_ERV8_STO
# 8                                   eReserve9           AB_ERV9_STO
# 9                                  Summerview           AB_SUM1_STO
# 10                   Summerland Energy Centre          BC_SML01_STO
# 11                                Spider Lake           NS_132H_STO
# 12                                  Canaan Rd            NS_43V_STO
# 13                                Bridgewater            NS_99W_STO
# 14                                        903          ON_90300_STO
# 15                               Almonte BESS          ON_ALM00_STO
# 16                        AM-Energy Storage 1          ON_AM100_STO
# 17                        AM Energy Storage 2          ON_AM200_STO
# 18                     Arlen Energy Storage 1          ON_ARI00_STO
# 19                                  Beck Pump          ON_BKP00_STO
# 20                                    Ellwood          ON_ELW00_STO
# 21                                     Elmira          ON_EMA00_STO
# 22                                     Guelph          ON_GLP00_STO
# 23                      Goderich CAES Project          ON_GOD00_STO
# 24                               Goreway BESS          ON_GRW00_STO
# 25  Hagersville Battery Energy Storage ParkÂ           ON_HGV00_STO
# 26                                  Kitchener          ON_KTH00_STO
# 27                     Napanee Energy Storage          ON_NAP00_STO
# 28                      Oneida Energy Storage          ON_ONE00_STO
# 29                                       OZ-1          ON_OZ100_STO
# 30                                      Parry          ON_PRS00_STO
# 31                                     SFF 06         ON_SFF600_STO
# 32                            Sault Ste Marie          ON_SSM00_STO
# 33                                  Stratford          ON_STF00_STO
# 34                    Tilbury Battery Storage          ON_TLB00_STO
# 35                Vaughan 1E Energy Storage 1         ON_VGN100_STO
# 36                 Vaughan 3 Energy Storage 1         ON_VGN300_STO
# 37                              Walker BESS 4         ON_WLK400_STO
# 38                              Walker BESS 5         ON_WLK500_STO
# 39                              Walker BESS 6         ON_WLK600_STO
# 40                                  York BESS            ON_YRK_STO
# 41                        Slemon Park Storage          PE_SLP00_STO
# 42                         Summerside Storage          PE_SMS00_STO
# 43                            Gabrielle-Bodis            QC_GBO_STO
# 44                                Hemmingford            QC_HMF_STO
# 45                               Fleet Street            SK_FLS_STO
#
#                                                 owner province  \
# 0                                Enfinite Corporation       AB
# 1                                Enfinite Corporation       AB
# 2                                Enfinite Corporation       AB
# 3                                Enfinite Corporation       AB
# 4                                Enfinite Corporation       AB
# 5                                Enfinite Corporation       AB
# 6                                Enfinite Corporation       AB
# 7                                Enfinite Corporation       AB
# 8                                Enfinite Corporation       AB
# 9                               TransAlta Corporation       AB
# 10                             District of Summerland       BC
# 11                             Nova Scotia Power Inc.       NS
# 12                             Nova Scotia Power Inc.       NS
# 13                             Nova Scotia Power Inc.       NS
# 14                            1000234763 Ontario Inc.       ON
# 15                  Walker BESS 4 Limited Partnership       ON
# 16             Ameresco Newmarket Energy Storage Inc.       ON
# 17             Ameresco Newmarket Energy Storage Inc.       ON
# 18                          Arlen Energy Storage 1 LP       ON
# 19                       Ontario Power Generation Inc       ON
# 20                                Hydro Ottawa / CIMA       ON
# 21                                     Nextera Energy       ON
# 22                          Convergent Energy & Power       ON
# 23                          NRStor Goderich CAES L.P.       ON
# 24                               Goreway Battery L.P.       ON
# 25                    Hagersville Battery Storage Inc       ON
# 26                       Hecate Energy / Powin Energy       ON
# 27                                  Napanee BESS Inc.       ON
# 28  Nstor / Six Nations of the Grand River Develop...       ON
# 29                            1000234813 Ontario Inc.       ON
# 30                                     Nextera Energy       ON
# 31                            1000234763 Ontario Inc.       ON
# 32                          Convergent Energy & Power       ON
# 33                       Hecate Energy / Powin Energy       ON
# 34                        Tilbury Battery Storage Inc       ON
# 35                     Vaughan 1E Energy Storage 1 LP       ON
# 36                      Vaughan 3 Energy Storage 1 LP       ON
# 37                  Walker BESS 4 Limited Partnership       ON
# 38                  Walker BESS 4 Limited Partnership       ON
# 39                  Walker BESS 4 Limited Partnership       ON
# 40                                    York Battery LP       ON
# 41                                  Maritime Electric       PE
# 42                                Summerside Electric       PE
# 43                                               EVLO       QC
# 44                                               EVLO       QC
# 45                                          Saskpower       SK
#
#             location   latitude    longitude  elevation  \
# 0            Rycroft  55.739640  -118.700692        613
# 1             Jarrow  53.118500  -111.200787        668
# 2     Clairmont Lake  55.287854  -118.643341        682
# 3           Hardisty  52.608139  -111.245123        700
# 4          Hughenden  52.493449  -110.934438        700
# 5           Hardisty  52.608139  -111.249034        700
# 6             Wapiti  54.962625  -119.192732        701
# 7             Wapiti  54.962524  -119.192504        701
# 8              Hythe  55.286251  -119.611149        759
# 9      Pincher Creek  49.582900  -113.793117       1072
# 10        Summerland  49.595331  -119.700804        555
# 11          Waverley  44.743794   -63.550192         80
# 12         Wolfville  45.048073   -64.421552        110
# 13       Bridgewater  44.395228   -64.555173         63
# 14       Burks Falls  45.597353   -79.405975        320
# 15           Almonte  45.201774   -76.182849        135
# 16         Newmarket  44.063933   -79.426439        280
# 17         Newmarket  44.063947   -79.426266        280
# 18            Guelph  43.486984   -80.206028        338
# 19     Niagara Falls  43.144600   -79.059900        177
# 20            Ottawa  45.371474   -75.647189         88
# 21            Elmira  43.603247   -80.552756        349
# 22            Guelph  43.486536   -80.205401        338
# 23          Goderich  43.753946   -81.715182        193
# 24          Brampton  43.744164   -79.682329        177
# 25       Hagersville  42.927048   -80.120020        215
# 26         Kitchener  43.445545   -80.455804        314
# 27              Bath  44.153117   -76.835433         77
# 28            Jarvis  42.827362   -80.060487        192
# 29           Chesley  44.291354   -81.097120        280
# 30       Parry Sound  45.302485   -79.945380        215
# 31           Grafton  44.068008   -77.936925        200
# 32  Sault Ste. Marie  46.520550   -84.279553        200
# 33         Stratford  43.349687   -81.014656        363
# 34           Tilbury  42.279617   -82.438117        177
# 35           Concord  43.810377   -79.478426        198
# 36        Woodbridge  43.804393   -79.646568        188
# 37           Windsor  42.288801   -82.965538        184
# 38           Windsor  42.288508   -82.965427        184
# 39           Windsor  42.288392   -82.965351        184
# 40         Newmarket  44.076893   -79.531076        239
# 41        Summerside  46.438170   -63.823704         25
# 42        Summerside  46.402906   -63.812439         15
# 43        La Prairie  45.411900   -73.435052         17
# 44       Hemmingford  45.072732   -73.578268         64
# 45            Regina  50.478749  -104.547482        587
#
#      copper_balancing_area      operating_region  ... possible_renewal_year  \
# 0                Alberta.a               Alberta  ...                  2040
# 1                Alberta.a               Alberta  ...                  2040
# 2                Alberta.a               Alberta  ...                  2043
# 3                Alberta.a               Alberta  ...                  2043
# 4                Alberta.a               Alberta  ...                  2043
# 5                Alberta.a               Alberta  ...                  2043
# 6                Alberta.a               Alberta  ...                  2044
# 7                Alberta.a               Alberta  ...                  2044
# 8                Alberta.a               Alberta  ...                  2044
# 9                Alberta.a               Alberta  ...                  2040
# 10      British Columbia.a      British Columbia  ...                  2043
# 11           Nova Scotia.a           Nova Scotia  ...                  2045
# 12           Nova Scotia.a           Nova Scotia  ...                  2046
# 13           Nova Scotia.a           Nova Scotia  ...                  2045
# 14               Ontario.a               Ontario  ...                  2041
# 15               Ontario.a               Ontario  ...                  2046
# 16               Ontario.a               Ontario  ...                  2028
# 17               Ontario.a               Ontario  ...                  2028
# 18               Ontario.a               Ontario  ...                  2041
# 19               Ontario.a               Ontario  ...                  2066
# 20               Ontario.b               Ontario  ...                  2031
# 21               Ontario.a               Ontario  ...                  2028
# 22               Ontario.a               Ontario  ...                  2031
# 23               Ontario.a               Ontario  ...                  2029
# 24               Ontario.a               Ontario  ...                  2041
# 25               Ontario.a               Ontario  ...                  2048
# 26               Ontario.a               Ontario  ...                  2031
# 27               Ontario.a               Ontario  ...                  2041
# 28               Ontario.a               Ontario  ...                  2045
# 29               Ontario.a               Ontario  ...                  2041
# 30               Ontario.b               Ontario  ...                  2028
# 31               Ontario.a               Ontario  ...                  2041
# 32               Ontario.b               Ontario  ...                  2031
# 33               Ontario.a               Ontario  ...                  2034
# 34               Ontario.a               Ontario  ...                  2041
# 35               Ontario.a               Ontario  ...                  2041
# 36               Ontario.a               Ontario  ...                  2041
# 37               Ontario.a               Ontario  ...                  2046
# 38               Ontario.a               Ontario  ...                  2046
# 39               Ontario.a               Ontario  ...                  2046
# 40               Ontario.a               Ontario  ...                  2041
# 41  Prince Edward Island.a  Prince Edward Island  ...                  2040
# 42  Prince Edward Island.a  Prince Edward Island  ...                  2040
# 43                Quebec.a                Quebec  ...                  2036
# 44                Quebec.a                Quebec  ...                  2032
# 45          Saskatchewan.a          Saskatchewan  ...                  2044
#
#    closure_year      storage_type storage_type_copper       storage_product  \
# 0           NaN   storage_lithium          storage_LI        energy storage
# 1           NaN   storage_lithium          storage_LI        energy storage
# 2           NaN   storage_lithium          storage_LI        energy storage
# 3           NaN   storage_lithium          storage_LI        energy storage
# 4           NaN   storage_lithium          storage_LI        energy storage
# 5           NaN   storage_lithium          storage_LI        energy storage
# 6           NaN   storage_lithium          storage_LI        energy storage
# 7           NaN   storage_lithium          storage_LI        energy storage
# 8           NaN   storage_lithium          storage_LI        energy storage
# 9           NaN   storage_lithium          storage_LI        energy storage
# 10          NaN   storage_lithium          storage_LI        energy storage
# 11          NaN   storage_lithium          storage_LI        energy storage
# 12          NaN   storage_lithium          storage_LI        energy storage
# 13          NaN   storage_lithium          storage_LI        energy storage
# 14          NaN   storage_lithium          storage_LI        energy storage
# 15          NaN   storage_lithium          storage_LI        energy storage
# 16          NaN     storage_solid          storage_LI        energy storage
# 17          NaN     storage_solid          storage_LI        energy storage
# 18          NaN   storage_lithium          storage_LI        energy storage
# 19          NaN      storage_pump          storage_PH        energy storage
# 20          NaN   storage_lithium          storage_LI       voltage control
# 21          NaN     storage_solid          storage_LI        energy storage
# 22          NaN  storage_flywheel          storage_LI  frequency regulation
# 23          NaN       storage_air          storage_LI        energy storage
# 24          NaN   storage_lithium          storage_LI        energy storage
# 25          NaN   storage_lithium          storage_LI        energy storage
# 26          NaN   storage_lithium          storage_LI       voltage control
# 27          NaN   storage_lithium          storage_LI        energy storage
# 28          NaN   storage_lithium          storage_LI        energy storage
# 29          NaN   storage_lithium          storage_LI        energy storage
# 30          NaN     storage_solid          storage_LI        energy storage
# 31          NaN   storage_lithium          storage_LI        energy storage
# 32          NaN   storage_lithium          storage_LI       voltage control
# 33          NaN   storage_lithium          storage_LI        energy storage
# 34          NaN   storage_lithium          storage_LI        energy storage
# 35          NaN   storage_lithium          storage_LI        energy storage
# 36          NaN   storage_lithium          storage_LI        energy storage
# 37          NaN   storage_lithium          storage_LI        energy storage
# 38          NaN   storage_lithium          storage_LI        energy storage
# 39          NaN   storage_lithium          storage_LI        energy storage
# 40          NaN   storage_lithium          storage_LI        energy storage
# 41          NaN   storage_lithium          storage_LI        energy storage
# 42          NaN   storage_lithium          storage_LI        energy storage
# 43          NaN   storage_lithium     storage_lithium        energy storage
# 44          NaN   storage_lithium     storage_lithium        energy storage
# 45       2044.0   storage_lithium          storage_LI        energy storage
#
#     storage_capacity  storage_energy  storage_duration  associated_generation  \
# 0                 20              35              1.75                   Grid
# 1                 20              35              1.75                   Grid
# 2                 20              35              1.75                   Grid
# 3                 20              35              1.75                   Grid
# 4                 20              35              1.75                   Grid
# 5                 20              35              1.75                   Grid
# 6                 20              35              1.75                   Grid
# 7                 20              35              1.75                   Grid
# 8                 20              35              1.75                   Grid
# 9                 10              20              2.00           Summerview 2
# 10                 1               4              4.00               solar_pv
# 11                50             200              4.00                   Grid
# 12                50             200              4.00                   Grid
# 13                50             200              4.00                   Grid
# 14                 5              19              4.00                   Grid
# 15                 5              19              4.00                   Grid
# 16                 3              10              4.00                   Grid
# 17                 3              10              4.00                   Grid
# 18                19              76              4.00                   Grid
# 19               174             600              3.50                   Grid
# 20                 4               3              0.75                   Grid
# 21                 2               8              4.00                   Grid
# 22                 5               1              0.10                   Grid
# 23                 2               7              4.00                   Grid
# 24                48             190              4.00                   Grid
# 25               285            1140              4.00                   Grid
# 26                 2               6              3.00                   Grid
# 27               250            1000              4.00                   Grid
# 28               250            1000              4.00                   Grid
# 29                 5              19              4.00                   Grid
# 30                 2               8              4.00                   Grid
# 31                 5              19              4.00                   Grid
# 32                 7               7              1.00                   Grid
# 33                 9              41              4.59                   Grid
# 34                76             304              4.00                   Grid
# 35                19              76              4.00                   Grid
# 36                38             152              4.00                   Grid
# 37                 5              19              4.00                   Grid
# 38                 5              19              4.00                   Grid
# 39                 5              19              4.00                   Grid
# 40               114             456              4.00                   Grid
# 41                 1               2              2.00                   Grid
# 42                10              20              2.00                Sunbank
# 43                 2               4              2.00        Gabrielle-Bodis
# 44                 1               2              2.00                   Grid
# 45                20              20              1.00                   Grid
#
#                                    notes
# 0                                   NULL
# 1                                   NULL
# 2                                   NULL
# 3                                   NULL
# 4                                   NULL
# 5                                   NULL
# 6                                   NULL
# 7                                   NULL
# 8                                   NULL
# 9                                   NULL
# 10                                  NULL
# 11                   Also called Waverly
# 12                Also called The Valley
# 13                                  NULL
# 14                                  NULL
# 15                                  NULL
# 16                                  NULL
# 17                                  NULL
# 18                                  NULL
# 19  Facility operates only when required
# 20  No longer under contract to the IESO
# 21                                  NULL
# 22  No longer under contract to the IESO
# 23                                  NULL
# 24                                  NULL
# 25                                  NULL
# 26  No longer under contract to the IESO
# 27                                  NULL
# 28                                  NULL
# 29                                  NULL
# 30                                  NULL
# 31                                  NULL
# 32  No longer under contract to the IESO
# 33  No longer under contract to the IESO
# 34                                  NULL
# 35                                  NULL
# 36                                  NULL
# 37                                  NULL
# 38                                  NULL
# 39                                  NULL
# 40                                  NULL
# 41                                  NULL
# 42                                  NULL
# 43                                  NULL
# 44                                  NULL
# 45                                  NULL
#
# [46 rows x 27 columns]

# %%
import requests
import json
import pandas as pd

# Function for saving
def save_coders_table_2_csv(x,filepath):
    "Function converts CODERS json tables ([{},...,{}]) to a dataframe and then saves it."
    pd.DataFrame.from_records(x.json()).to_csv(filepath, index=False)

# Path to save data to
path = f"CODERS/data-pull"

# %%
# Code to look at table names
x = requests.get('http://206.12.95.90/tables') # send request 
print(x.json()) # print response

# %% [markdown]
# ### Code to pull all generators data
# Tables: generators, generation_cost_evolution, generation_generic, hydro_existing, generation_planning_reserve, hydro_cascade, wind_generators

# %%
# store generators
table = "generators"
generators = requests.get(f'http://206.12.95.90/{table}') # sensubstationsd request 
filepath = path + "/" + table + ".csv"
save_coders_table_2_csv(generators,filepath)

# %%
# store generation_cost_evolution
table = "generation_cost_evolution"
x = requests.get(f'http://206.12.95.90/{table}') # sensubstationsd request 
filepath = path + "/" + table + ".csv"
save_coders_table_2_csv(x,filepath)

# %%
# store generation_generic
table = "generation_generic"
x = requests.get(f'http://206.12.95.90/{table}') # sensubstationsd request 
filepath = path + "/" + table + ".csv"
# x.json()[0]
save_coders_table_2_csv(x,filepath)

# %%
# store hydro_existing
table = "hydro_existing"
x = requests.get(f'http://206.12.95.90/{table}') # sensubstationsd request 
filepath = path + "/" + table + ".csv"
# x.json()[1]
save_coders_table_2_csv(x,filepath)

# %%
# store generation_planning_reserve
table = "generation_planning_reserve"
x = requests.get(f'http://206.12.95.90/{table}') # sensubstationsd request 
filepath = path + "/" + table + ".csv"
# x.json()[1
save_coders_table_2_csv(x,filepath)

# %%
# store hydro_cascade
table = "hydro_cascade"
x = requests.get(f'http://206.12.95.90/{table}') # sensubstationsd request 
filepath = path + "/" + table + ".csv"
# x.json()[1]
save_coders_table_2_csv(x,filepath)

# %%
# store wind_generators
table = "wind_generators"
x = requests.get(f'http://206.12.95.90/{table}') # sensubstationsd request 
filepath = path + "/" + table + ".csv"
# x.json()[1]
save_coders_table_2_csv(x,filepath)

# %% [markdown]
# ### Code to pull transmission and network data
# Tables:  transmission_lines, substations, interties, interface_capacities, transfer_capacities_copper, intertie_capacity, transmission_generic

# %%
# store transmission_lines
table = "transmission_lines"
x = requests.get(f'http://206.12.95.90/{table}') # sensubstationsd request 
filepath = path + "/" + table + ".csv"
# x.json()[0]
save_coders_table_2_csv(x,filepath)

# %%
# store substations
table = "substations"
x = requests.get(f'http://206.12.95.90/{table}') # sensubstationsd request 
filepath = path + "/" + table + ".csv"
# x.json()[0]
save_coders_table_2_csv(x,filepath)

# %%
# store interties
table = "interties"
x = requests.get(f'http://206.12.95.90/{table}') # sensubstationsd request 
filepath = path + "/" + table + ".csv"
# x.json()[0]
save_coders_table_2_csv(x,filepath)

# %%
# store interface_capacities
table = "interface_capacities"
x = requests.get(f'http://206.12.95.90/{table}') # sensubstationsd request 
filepath = path + "/" + table + ".csv"
# x.json()[0]
save_coders_table_2_csv(x,filepath)

# %%
# store transfer_capacities_copper
table = "transfer_capacities_copper"
x = requests.get(f'http://206.12.95.90/{table}') # sensubstationsd request 
filepath = path + "/" + table + ".csv"
# x.json()[0]
save_coders_table_2_csv(x, filepath)

# %%
# store intertie_capacity
table = "intertie_capacity"
x = requests.get(f'http://206.12.95.90/{table}') # sensubstationsd request 
filepath = path + "/" + table + ".csv"
# x.json()[0]
save_coders_table_2_csv(x, filepath)

# %%
# store transmission_generic
table = "transmission_generic"
x = requests.get(f'http://206.12.95.90/{table}') # sensubstationsd request 
filepath = path + "/" + table + ".csv"
# x.json()[0]
save_coders_table_2_csv(x, filepath)

# %% [markdown]
# ### Code to pull demand data
# Tables: provincial_demand, forecasted_annual_demand, forecasted_peak_demand

# %%
# store provincial_demand
table = "provincial_demand"
y = []
for year in [2018,2019,2020]: # 2021 had only 1 piece of data..
    x = requests.get(f'http://206.12.95.90/{table}?year={year}&province=BC') # sensubstationsd request
    y = y + x.json()

filepath = path + "/" + table + ".csv"

pd.DataFrame.from_records(y).to_csv(filepath, index=False)
    # save_coders_table_2_csv(x, filepath)

# %%
# store forecasted_annual_demand
table = "forecasted_annual_demand"
x = requests.get(f'http://206.12.95.90/{table}') # sensubstationsd request 
filepath = path + "/" + table + ".csv"
# x.json()[0]
save_coders_table_2_csv(x, filepath)

# %%
# store forecasted_peak_demand
table = "forecasted_peak_demand"
x = requests.get(f'http://206.12.95.90/{table}') # sensubstationsd request 
filepath = path + "/" + table + ".csv"
# x.json()[0]
save_coders_table_2_csv(x, filepath)

# %% [markdown]
# ### Code to pull references

# %%
# store references
table = "references"
x = requests.get(f'http://206.12.95.90/{table}') # sensubstationsd request 
filepath = path + "/" + table + ".csv"
# x.json()[0]
save_coders_table_2_csv(x, filepath)
