# %% [markdown]
# > Building;  EL_20260724

# %%
from workflow.scripts import create_cutout
create_cutout.main()
# Out:
# Preparing cutout...
# 2026-07-25 11:12:31,410 - INFO - Building new cutout data/downloaded_data/cutoutBC_2021_2022.nc
# 2026-07-25 11:12:31,428 - INFO - Storing temporary files in /tmp/tmphhmj7mhg
# 2026-07-25 11:12:31,431 - INFO - Calculating and writing with module era5:
# 2026-07-25 11:12:31,434 - INFO - Requesting data for feature runoff...
# 2026-07-25 11:12:31,436 - INFO - Requesting data for feature influx...
# 2026-07-25 11:12:31,437 - INFO - Requesting data for feature height...
# 2026-07-25 11:12:31,439 - INFO - Requesting data for feature temperature...
# 2026-07-25 11:12:31,440 - INFO - Requesting data for feature wind...
# 2026-07-25 11:18:56,331 - INFO - CDS: Downloading variables
# 	10m_u_component_of_wind (['2021']-['01'])
# 	10m_v_component_of_wind (['2021']-['01'])
# 	100m_u_component_of_wind (['2021']-['01'])
# 	100m_v_component_of_wind (['2021']-['01'])
# 	forecast_surface_roughness (['2021']-['01'])
#
# ...

# %% [markdown]
# ## Stage 2 : Assets

# %% [markdown]
# [x] Wind Assets

# %%
# from workflow.scripts import prepare_ror

# # prepare_wind.main()                 # fetch CWTD → turbine dict → wind assets
# prepare_ror.main()   # re-download CWTD first
