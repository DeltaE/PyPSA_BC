# %% [markdown]
# > Building;  EL_20260724

# %% [markdown]
# Stage 2
# ---

# %% [markdown]
# # PyPSA-BC : Prepare Assets data

# %% [markdown]
# [x] Hydro

# %%
from workflow.scripts import prepare_hydro
prepare_hydro.main()
# Out:
# 2026-07-25 22:47:01,386 - INFO - Note: NumExpr detected 32 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 16.
# 2026-07-25 22:47:01,386 - INFO - NumExpr defaulting to 16 threads.
# Hydro assets — 3 stages: CODERS tables, hydro cascade, hydro assets
# → hydro assets (3/3) |██████▋   | 00:00
# ✓ CODERS tables  (0.0s)
# >> legacy hydro_cascade built: 76 turbine rows, 33 columns
# >> written: data/processed_data/hydro/existing/hydro_cascade.csv
# ✓ hydro cascade  (0.0s)
# Hydro assets: complete |██████████| 00:00
# ✓ hydro assets  (0.2s)
#
# Hydro assets preparation completed. Delivered:
# ┌────────────────────────┬─────────────────────────────────────────────────────────────────────┬──────┐
# │ File                   │ Path                                                                │ Rows │
# ├────────────────────────┼─────────────────────────────────────────────────────────────────────┼──────┤
# │ generators.csv         │ data/downloaded_data/CODERS/data-pull/supply/generators.csv         │ 268  │
# │ generation_generic.csv │ data/downloaded_data/CODERS/data-pull/supply/generation_generic.csv │ 30   │
# │ existing_hydro.csv     │ data/downloaded_data/CODERS/data-pull/supply/existing_hydro.csv     │ 208  │
# │ hydro_cascade.csv      │ data/processed_data/hydro/existing/hydro_cascade.csv                │ 76   │
# │ hydro_generation.csv   │ data/processed_data/hydro/existing/hydro_generation.csv             │ 118  │
# │ hydro_reservoirs.csv   │ data/processed_data/hydro/existing/hydro_reservoirs.csv             │ 21   │
# └────────────────────────┴─────────────────────────────────────────────────────────────────────┴──────┘

# %% [markdown]
# [x] Wind

# %%
from workflow.scripts import prepare_wind
prepare_wind.main()
# Out:
# Wind assets — 4 stages: fetch CWTD, CODERS tables, turbine dict, wind assets
# → turbine dict (3/4) |█████     | 00:00
# ✓ fetch CWTD  (0.0s)
# ✓ CODERS tables  (0.0s)
# 2026-07-25 22:47:35,861 - INFO - Searching turbine power curve in OEDB database using .
# 2026-07-25 22:47:35,863 - WARNING - Multiple values for hub_height in dataset ([69.0, 78.0, 84.0]). Manual clean-up required. Using the averge 77m for now.
# 2026-07-25 22:47:35,865 - INFO - Searching turbine power curve in OEDB database using .
# 2026-07-25 22:47:35,868 - WARNING - Multiple values for hub_height in dataset ([99.0, 135.0, 159.0]). Manual clean-up required. Using the averge 131m for now.
# 2026-07-25 22:47:35,869 - INFO - Searching turbine power curve in OEDB database using .
# 2026-07-25 22:47:35,871 - INFO - Searching turbine power curve in OEDB database using .
# 2026-07-25 22:47:35,873 - INFO - Searching turbine power curve in OEDB database using .
# 2026-07-25 22:47:35,874 - INFO - Searching turbine power curve in OEDB database using .
# 2026-07-25 22:47:35,876 - INFO - Searching turbine power curve in OEDB database using .
# 2026-07-25 22:47:35,877 - INFO - Searching turbine power curve in OEDB database using .
# 2026-07-25 22:47:35,878 - INFO - Searching turbine power curve in OEDB database using .
# 2026-07-25 22:47:35,879 - INFO - Searching turbine power curve in OEDB database using .
# 2026-07-25 22:47:35,880 - INFO - Searching turbine power curve in OEDB database using .
# 2026-07-25 22:47:35,881 - INFO - Searching turbine power curve in OEDB database using .
# 2026-07-25 22:47:35,881 - INFO - Searching turbine power curve in OEDB database using .
# 2026-07-25 22:47:35,882 - INFO - Searching turbine power curve in OEDB database using .
# 2026-07-25 22:47:35,883 - INFO - Searching turbine power curve in OEDB database using .
# 2026-07-25 22:47:35,884 - INFO - Searching turbine power curve in OEDB database using .
# 2026-07-25 22:47:35,884 - INFO - Searching turbine power curve in OEDB database using .
# → wind assets (4/4) |███████▌  | 00:02
#     ⚠ [build_turbine_dict] inventory fallback used (OEDB not resolved): ['V90-1.8', 'V100-1.8', 'GE 2.75-120', 'GE 3.2-103', '3.2-MM114', 'LTW77-1.5']
# ✓ turbine dict  (2.3s)
# Wind assets: complete |██████████| 00:02
# ✓ wind assets  (0.6s)
#
# Wind assets preparation completed. Delivered:
# ┌────────────────────────┬─────────────────────────────────────────────────────────────────────┬────────────────────────────────┐
# │ File                   │ Path                                                                │ Rows                           │
# ├────────────────────────┼─────────────────────────────────────────────────────────────────────┼────────────────────────────────┤
# │ canada_turbines.xlsx   │ data/downloaded_data/wind/canada_turbines.xlsx                      │ 0.7 MB                         │
# │ generators.csv         │ data/downloaded_data/CODERS/data-pull/supply/generators.csv         │ 268                            │
# │ generation_generic.csv │ data/downloaded_data/CODERS/data-pull/supply/generation_generic.csv │ 30                             │
# │ turbine_dict.json      │ data/downloaded_data/wind/turbine_dict.json                         │ 9 models, 6 inventory-fallback │
# │ wind_assets.csv        │ data/processed_data/wind/existing/bc_ext_wind_assets.csv            │ 10                             │
# └────────────────────────┴─────────────────────────────────────────────────────────────────────┴────────────────────────────────┘

# %% [markdown]
# [x] Solar

# %%
from workflow.scripts import prepare_solar
prepare_solar.main()
# Out:
# Solar assets — 2 stages: CODERS tables, solar assets
# Solar assets: complete |██████████| 00:00
# ✓ CODERS tables  (0.0s)
# ✓ solar assets  (0.0s)
#
# Solar assets preparation completed. Delivered:
# ┌────────────────────────┬─────────────────────────────────────────────────────────────────────┬──────┐
# │ File                   │ Path                                                                │ Rows │
# ├────────────────────────┼─────────────────────────────────────────────────────────────────────┼──────┤
# │ generators.csv         │ data/downloaded_data/CODERS/data-pull/supply/generators.csv         │ 268  │
# │ generation_generic.csv │ data/downloaded_data/CODERS/data-pull/supply/generation_generic.csv │ 30   │
# │ solar_assets.csv       │ data/processed_data/solar/existing/bc_ext_solar_assets.csv          │ 3    │
# └────────────────────────┴─────────────────────────────────────────────────────────────────────┴──────┘

# %% [markdown]
# [x] Thermal

# %%
from workflow.scripts import prepare_tpp
prepare_tpp.main()
# Out:
# TPP assets — 2 stages: CODERS tables, tpp assets
# TPP assets: complete |██████████| 00:00
# ✓ CODERS tables  (0.0s)
#     ⚠ [utils] create_standard_gen_bus_map: skipped 1 bus(es) with no valid name: [nan]
# ✓ tpp assets  (0.0s)
#
# TPP assets preparation completed. Delivered:
# ┌────────────────────────┬─────────────────────────────────────────────────────────────────────┬──────┐
# │ File                   │ Path                                                                │ Rows │
# ├────────────────────────┼─────────────────────────────────────────────────────────────────────┼──────┤
# │ generators.csv         │ data/downloaded_data/CODERS/data-pull/supply/generators.csv         │ 268  │
# │ generation_generic.csv │ data/downloaded_data/CODERS/data-pull/supply/generation_generic.csv │ 30   │
# │ tpp_assets.csv         │ data/processed_data/tpp/existing/bc_ext_tpp_assets.csv              │ 38   │
# └────────────────────────┴─────────────────────────────────────────────────────────────────────┴──────┘

# %% [markdown]
# [~] RoR

# %%
from workflow.scripts import prepare_ror
prepare_ror.main()
# Out:
# 2026-07-25 22:42:00,338 - INFO - Note: NumExpr detected 32 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 16.
# 2026-07-25 22:42:00,338 - INFO - NumExpr defaulting to 16 threads.
# RoR power series — 1 stages: ror power series
# → ror power series (1/1) |          | 00:00/localhome/mei3/eliasinul/work/PyPSA_BC/.venv/lib/python3.12/site-packages/xarray/backends/plugins.py:109: RuntimeWarning: Engine 'cfgrib' loading failed:
# Cannot find the ecCodes library
#   external_backend_entrypoints = backends_dict_from_pkg(entrypoints_unique)
# RoR power series: complete |██████████| 00:15
# ✓ ror power series  (15.3s)
#
# RoR power series preparation completed. Delivered:
# ┌───────────────────┬──────────────────────────────────────────────────────┬──────┐
# │ File              │ Path                                                 │ Rows │
# ├───────────────────┼──────────────────────────────────────────────────────┼──────┤
# │ bc_ext_ror_ts.csv │ data/processed_data/hydro/existing/bc_ext_ror_ts.csv │ 8760 │
# └───────────────────┴──────────────────────────────────────────────────────┴──────┘
