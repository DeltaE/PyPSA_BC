# %% [markdown]
# Stage 1
# ---

# %% [markdown]
# # PyPSA-BC : Prepare Base Network

# %%
from workflow.scripts import prepare_base_network
prepare_base_network.main()
# Out:
# Base network — 3 stages: lines, buses, transformers
# → buses (2/3) |███▎      | 00:00
# ✓ lines  (0.1s)
# → buses (2/3) |███▎      | 00:13
#     ⚠ [buses] no information to create bus for: BC_GST_JCT
#     ⚠ [buses] no information to create bus for: BC_GST_JCT
# Base network: complete |██████████| 00:16
#     ⚠ [buses] substation code WEY is missing from the lines dataset
# ✓ buses  (16.7s)
#     ⚠ [transformers] skipped 1 bus row(s) with non-string name: [812]
# ✓ transformers  (0.0s)
#
# Base network preparation completed. Delivered:
# ┌───────────────────────┬───────────────────────────────────────────────────┬───────────────────────┬───────────┐
# │ File                  │ Path                                              │ Data Shape            │ Size      │
# ├───────────────────────┼───────────────────────────────────────────────────┼───────────────────────┼───────────┤
# │ lines.csv             │ data/processed_data/network/lines.csv             │ Rows 1239, Columns 36 │ 308.69 KB │
# │ line_types.csv        │ data/processed_data/network/line_types.csv        │ Rows 34, Columns 14   │ 2.63 KB   │
# │ buses.csv             │ data/processed_data/network/buses.csv             │ Rows 1010, Columns 5  │ 41.79 KB  │
# │ transformers.csv      │ data/processed_data/network/transformers.csv      │ Rows 110, Columns 4   │ 5.03 KB   │
# │ transformer_types.csv │ data/processed_data/network/transformer_types.csv │ Rows 18, Columns 15   │ 1.07 KB   │
# └───────────────────────┴───────────────────────────────────────────────────┴───────────────────────┴───────────┘
