# %% [markdown]
# Stage 4
# ----

# %% [markdown]
# # PyPSA-BC : Data handover for model

# %%
from workflow.scripts import prepare_data_handover
prepare_data_handover.main(run_vre_dict=True,
    run_tpp_dict=True,
    run_hydro_dict=True,
    force_update=True)
# Out:
# 2026-07-26 09:37:44,704 - INFO - Note: NumExpr detected 32 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 16.
# 2026-07-26 09:37:44,705 - INFO - NumExpr defaulting to 16 threads.
# Data handover to PyPSA — 3 stages: vre dict, tpp dict, hydro dict
# → vre dict (1/3) |          | 00:002026-07-26 09:37:45,835 - WARNING - >> Given instance for 'destination (save_to)' is of type: <class 'str'>. Converting it to a Path
# → hydro dict (3/3) |██████▋   | 00:002026-07-26 09:37:45,968 - WARNING - >> Given instance for 'destination (save_to)' is of type: <class 'str'>. Converting it to a Path
# → hydro dict (3/3) |██████▋   | 00:00
#     ⚠ [utils] create_standard_gen_bus_map: skipped 1 bus(es) with no valid name: [nan]
# ✓ vre dict  (0.1s)
#     ⚠ [utils] create_standard_gen_bus_map: skipped 1 bus(es) with no valid name: [nan]
#     ⚠ [enrich_format_tpp] Skipping TPP asset row=36 asset_id= node=BC_WEY_ISS gen_type=biomass (missing bus mapping for node 'WEY_ISS')
# ...
