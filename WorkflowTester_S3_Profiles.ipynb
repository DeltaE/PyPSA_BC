# %% [markdown]
# Stage 3
# ----

# %% [markdown]
# # PyPSA-BC : Profile data preparation workflow

# %%
from workflow.scripts import prepare_profiles
prepare_profiles.main(
    run_wind_ts=True,
    run_solar_ts=True,
    run_ror_power=True,
    run_reservoir_inflows=True,
    force_update=False
)
# Out:
# Profiles — 4 stages: wind ts, solar ts, ror power, reservoir inflows
# Profiles: complete |██████████| 00:00
# ✓ wind ts  (0.0s)
# ✓ solar ts  (0.0s)
# ✓ ror power  (0.0s)
# ✓ reservoir inflows  (0.0s)
#
# Profiles preparation completed. Delivered:
# ┌──────────────────────────────┬─────────────────────────────────────────────────────────────────┬───────────────────────┐
# │ File                         │ Path                                                            │ Rows                  │
# ├──────────────────────────────┼─────────────────────────────────────────────────────────────────┼───────────────────────┤
# │ bc_ext_wind_ts.csv           │ data/processed_data/wind/existing/bc_ext_wind_ts.csv            │ 8760 (exists locally) │
# │ bc_ext_solar_ts.csv          │ data/processed_data/solar/existing/bc_ext_solar_ts.csv          │ 8760 (exists locally) │
# ...
